# %%
import pandas as pd
from pymongo import MongoClient
import os

# %%
conn=MongoClient(f"mongodb+srv://{os.environ.get('USER_MONGO')}:{os.environ.get('MONGO_KEY')}@ufobrt.wyofdo3.mongodb.net/?retryWrites=true&w=majority")
conn.test
# Out:
# Database(MongoClient(host=['ac-9ypqmdn-shard-00-00.wyofdo3.mongodb.net:27017', 'ac-9ypqmdn-shard-00-02.wyofdo3.mongodb.net:27017', 'ac-9ypqmdn-shard-00-01.wyofdo3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-iov2ri-shard-0', tls=True), 'test')

# %%
result=conn.ufo_db.ufo_history.aggregate([
    {
        '$group': {
            '_id': '$city', 
            'count': {
                '$sum': 1
            }
        }
    }
])
for i in result:
    print(i)
# Out:
# {'_id': 'Clear Creek East Resort', 'count': 1}
# {'_id': 'Nine Mile River (Canada)', 'count': 1}
# {'_id': 'London East (UK/England)', 'count': 1}
# {'_id': 'Krimpen a/d Ijssel (Netherlands)', 'count': 1}
# {'_id': 'Long Beach/Los Angles', 'count': 1}
# {'_id': 'Cambridge City', 'count': 5}
# {'_id': 'Fifty Six', 'count': 1}
# {'_id': 'MM 110', 'count': 1}
# {'_id': 'Lindenhurst (Long Island)', 'count': 1}
# {'_id': 'Azucena', 'count': 1}
# {'_id': 'Truckee/Cisco Grove', 'count': 1}
# {'_id': 'San Andreas', 'count': 1}
# {'_id': 'North Liberty', 'count': 6}
# {'_id': 'Sihanoukville (Cambodia)', 'count': 1}
# {'_id': 'Otay Mesa', 'count': 1}
# {'_id': 'Ellenboro', 'count': 1}
# {'_id': 'Lewiston', 'count': 48}
# {'_id': 'Henderson/Las Vegas', 'count': 3}
# {'_id': 'Acoma Pueblo', 'count': 1}
# {'_id': 'Hasbrouck Heights', 'count': 2}
# {'_id': 'Clitherall', 'count': 1}
# {'_id': 'Waupaca', 'count': 11}
# {'_id': 'Ruwais (U.A.E.)', 'count': 1}
# {'_id': 'Lake Alpine', 'count': 3}
# {'_id': 'Somerviller', 'count': 1}
# {'_id': 'Lafayette (35 miles East of)', 'count': 2}
# {'_id': 'Clear Creek', 'count': 1}
# {'_id': 'Fair Oaks (landings)', 'count': 1}
# {'_id': 'Staffa (Canada)', 'count': 1}
# {'_id': 'Cala Gonone (Sardaigne) (Italy)', 'count': 1}
# {'_id': 'Newcastle upon Tyne', 'count': 2}
# {'_id': 'Richwood', 'count': 2}
# {'_id': 'Paso Robles (Lake Nacimiento Region)', 'count': 2}
# {'_id': 'Silver Lake (on the Fox River)', 'count': 1}
# {'_id': 'Winter Park (just outside Orlando)', 'count': 1}
# {'_id': 'Fairmont/Morgantown', 'count': 1}
# {'_id': 'Newborough (VIC, Australia)', 'count': 2}
# {'_id': 'Texas highway 54 heading into NM - after crossing I-10', 'count': 1}
# {'_id': 'Phoenix/Glendale (over)', 'count': 1}
# {'_id': 'Hart Mountain (near Lakeview)', 'count': 1}
# {'_id': 'Portland (suburbs)', 'count': 1}
# {'_id': 'Amsterdam (The Netherlands)', 'count': 2}
# {'_id': 'Hwy 168', 'count': 1}
# {'_id': 'Sligo', 'count': 2}
# {'_id': 'Peekskill', 'count': 11}
# {'_id': 'Rancho Cucamonga', 'count': 48}
# {'_id': 'Bainbridge Island', 'count': 21}
# {'_id': 'Carryville', 'count': 1}
# {'_id': 'Lander', 'count': 6}
# {'_id': 'Wynne', 'count': 2}
# {'_id': 'Concordville', 'count': 1}
# {'_id': 'Bossier Parish (southern)', 'count': 1}
# {'_id': 'Lancaster (Saddleback Butte Park)', 'count': 1}
# {'_id': 'Dix Hills', 'count': 5}
# {'_id': 'NJ Turnpike (Exit 3)', 'count': 1}
# {'_id': 'Newburgh/Village of Vails Gate', 'count': 1}
# {'_id': 'Mountain Home (outskirts of)', 'count': 1}
# {'_id': 'LITTLE ROCK', 'count': 1}
# {'_id': 'Egan', 'count': 6}
# {'_id': 'Praia (Santiago)', 'count': 1}
# {'_id': 'Maroochydore (Queensland) (Australia)', 'count': 1}
# {'_id': 'Dana Point', 'count': 24}
# {'_id': 'Fort Hall', 'count': 1}
# {'_id': 'Chaplin', 'count': 1}
# {'_id': 'Altmar', 'count': 1}
# {'_id': 'Pagham (Sussex) (UK/England)', 'count': 1}
# {'_id': 'Queensland (Australia)', 'count': 4}
# {'_id': 'Cincinnati (driving; from NY)', 'count': 1}
# {'_id': 'Topsail/Surf City', 'count': 1}
# {'_id': 'Tichborne (Canada)', 'count': 1}
# {'_id': 'Mars Hill', 'count': 6}
# {'_id': 'Comstock Park', 'count': 4}
# {'_id': 'New Shoreham', 'count': 1}
# {'_id': 'Silver Fork', 'count': 1}
# {'_id': 'Plant city', 'count': 1}
# {'_id': 'Spital (UK/England)', 'count': 1}
# {'_id': 'Malapascua Island (Philippines)', 'count': 1}
# {'_id': 'Endicott-Vestal', 'count': 1}
# {'_id': 'Krasnoyarsk (200km from) (Russia)', 'count': 1}
# {'_id': 'Cave Juntion', 'count': 1}
# {'_id': 'Zeeland (Holland area)', 'count': 1}
# {'_id': 'Idaho (rural)', 'count': 1}
# {'_id': 'I-5 (California', 'count': 1}
# {'_id': 'Yuba City', 'count': 18}
# {'_id': 'Frankin', 'count': 2}
# {'_id': 'Acambaro (Mexico)', 'count': 1}
# {'_id': 'Whitetail', 'count': 1}
# {'_id': 'New Braunfels', 'count': 26}
# {'_id': 'North Anson', 'count': 2}
# {'_id': 'Kawaihae', 'count': 1}
# {'_id': 'Anna', 'count': 6}
# {'_id': 'Child/Elkton (Cecil County)', 'count': 1}
# {'_id': 'HardwrickBay (Australia)', 'count': 1}
# {'_id': 'Regina, Saskatchewan (Canada)', 'count': 1}
# {'_id': 'Beach Park', 'count': 3}
# {'_id': 'Tonto Basin', 'count': 1}
# {'_id': 'South Phoenix/Laveen', 'count': 1}
# {'_id': 'Minot AFB', 'count': 3}
# {'_id': 'Petrified Forest National Park', 'count': 3}
# {'_id': 'Adelaide (Aldinga Beach) (South Australia)', 'count': 1}
# {'_id': 'Green Garden Township', 'count': 1}
# {'_id': 'Albuquerque (near)', 'count': 3}
# {'_id': 'Zarafshan (Uzbekistan)', 'count': 1}
# {'_id': 'Ciudad Lazaro Cardenas (Mexico)', 'count': 1}
# {'_id': 'Lakeland', 'count': 70}
# {'_id': 'Kinross', 'count': 2}
# {'_id': 'Spiceland', 'count': 2}
# {'_id': 'Rochester Hills', 'count': 23}
# {'_id': 'Port Sanilac', 'count': 3}
# {'_id': 'Raritan Township', 'count': 2}
# {'_id': 'Stone Creek', 'count': 2}
# {'_id': 'Bistib', 'count': 1}
# {'_id': 'Recife (Brazil)', 'count': 2}
# {'_id': 'Dyke access', 'count': 1}
# {'_id': 'Central Islip', 'count': 5}
# {'_id': 'Newport News (Fort Eustis)', 'count': 1}
# {'_id': 'Willcox', 'count': 4}
# {'_id': 'High Falls', 'count': 3}
# {'_id': 'United Kingdom (location unspecified)', 'count': 1}
# {'_id': 'Gracemont', 'count': 1}
# {'_id': 'Yuma (approx. 100 miles E of)', 'count': 1}
# {'_id': 'Nutley', 'count': 5}
# {'_id': 'Chicago (1 hours south ofoff I 57)', 'count': 1}
# {'_id': 'Logan city', 'count': 1}
# {'_id': 'Lawrenceburg/Columbia', 'count': 1}
# {'_id': 'Cumnock (UK/Scotland)', 'count': 1}
# {'_id': 'Eugen/Cottage Grove', 'count': 1}
# {'_id': 'Picacho', 'count': 1}
# {'_id': 'Gardiner', 'count': 6}
# {'_id': 'Bloomignton', 'count': 1}
# {'_id': 'Koeklare (Belgium)', 'count': 1}
# {'_id': 'Fort Worth (southwest of)', 'count': 1}
# {'_id': 'London (Chingford Hatch) (UK/England)', 'count': 1}
# {'_id': 'Oil City (near)', 'count': 1}
# {'_id': 'Willimantic', 'count': 2}
# {'_id': 'Sturgeon', 'count': 1}
# {'_id': 'Orillia (Canada)', 'count': 6}
# {'_id': 'Mankato Area', 'count': 1}
# {'_id': 'Gilman City', 'count': 2}
# {'_id': 'Maitland', 'count': 6}
# {'_id': 'Oakland', 'count': 100}
# {'_id': 'bloomfield', 'count': 1}
# {'_id': 'Rouyn Noranda (Canada)', 'count': 2}
# {'_id': 'Burhanpur (India', 'count': 1}
# {'_id': 'Verbena', 'count': 1}
# {'_id': 'Mesa/Chandler', 'count': 1}
# {'_id': 'Drakenstein, Paarl East (South Africa)', 'count': 1}
# {'_id': 'Stead', 'count': 1}
# {'_id': 'Woodinville (N.E. 189th Street)', 'count': 1}
# {'_id': 'Salina', 'count': 24}
# {'_id': 'Salem/Montrose (between)', 'count': 1}
# {'_id': 'Damascus (Boring)', 'count': 1}
# {'_id': 'I-5 North in Federal Way', 'count': 1}
# {'_id': 'Potsdam (Tupper Lake)', 'count': 1}
# {'_id': 'Cheltenham (UK/England)', 'count': 5}
# {'_id': 'Vale (Guernsey) (UK/England)', 'count': 1}
# {'_id': 'Llandovery (UK/Wales)', 'count': 1}
# {'_id': 'Wentworthville', 'count': 1}
# {'_id': 'Dhaka (Bangladesh)', 'count': 11}
# {'_id': 'Kinston/Richlands (between; Rt. 258)', 'count': 1}
# {'_id': 'California', 'count': 14}
# {'_id': 'Cottage Grove', 'count': 21}
# {'_id': 'Palm Desert (above)', 'count': 1}
# {'_id': 'New York Ciity (Brooklyn)', 'count': 1}
# {'_id': 'La Pointe', 'count': 1}
# {'_id': 'Palm bay', 'count': 1}
# {'_id': 'Holgate', 'count': 1}
# {'_id': 'Sallisaw', 'count': 8}
# {'_id': 'Berks County', 'count': 2}
# {'_id': 'Beverly', 'count': 21}
# {'_id': 'Tavistock (UK/England)', 'count': 1}
# {'_id': 'Napier (New Zealand)', 'count': 8}
# {'_id': 'Rainsville', 'count': 1}
# {'_id': 'Los Cabos (Mexico)', 'count': 1}
# {'_id': 'Heber Springs', 'count': 7}
# {'_id': 'Acton (Canada)', 'count': 4}
# {'_id': 'Strafford', 'count': 8}
# {'_id': 'Lancashire County (UK/England)', 'count': 1}
# {'_id': 'Las Cruces (on Interstate 10,west of)', 'count': 1}
# {'_id': 'Thackery', 'count': 1}
# {'_id': 'Matanzas Inlet', 'count': 1}
# {'_id': 'Blaine', 'count': 32}
# {'_id': 'Beacon Rock State Park (Skamania)', 'count': 1}
# {'_id': 'Groveland/Dillion (between)', 'count': 1}
# {'_id': 'Berea', 'count': 12}
# {'_id': 'Christ Church (Barbados)', 'count': 1}
# {'_id': 'Not sure', 'count': 1}
# {'_id': 'Millsap', 'count': 2}
# {'_id': 'Bagdad/Prescott', 'count': 1}
# {'_id': 'Tremonton', 'count': 2}
# {'_id': 'Pretoria (South Africa)', 'count': 12}
# {'_id': 'Poplar Grove', 'count': 3}
# {'_id': 'Jumping Branch', 'count': 1}
# {'_id': 'Beaver Dam (rural)', 'count': 1}
# {'_id': 'Mount Pleasant (Canada)', 'count': 1}
# {'_id': 'Sandakan (Sabah) (Malaysia)', 'count': 1}
# {'_id': 'Honiara (Aku Malaita) (Solomon Islands)', 'count': 1}
# {'_id': 'Maracay (Venezuela)', 'count': 1}
# {'_id': 'In flight (location unknown)', 'count': 1}
# {'_id': 'Mount Weather (near Leesburg)', 'count': 1}
# {'_id': 'Ocala', 'count': 81}
# {'_id': 'Taymouth (Canada)', 'count': 1}
# {'_id': 'Fort Coffee', 'count': 1}
# {'_id': 'Emerald Park (Canada)', 'count': 1}
# {'_id': 'Isabela (Puerto Rico)', 'count': 3}
# {'_id': 'Boston', 'count': 110}
# {'_id': 'San Diego (Lemon Grove)', 'count': 1}
# {'_id': 'Rakhine State (Myanmar)', 'count': 1}
# {'_id': 'Rasnov (Romania)', 'count': 1}
# {'_id': 'Galena', 'count': 8}
# {'_id': 'Kolymbia Beach (Greece)', 'count': 1}
# {'_id': 'Gary/Gary City', 'count': 1}
# {'_id': 'Fredonia (10 miles west of)', 'count': 1}
# {'_id': 'Trego', 'count': 1}
# {'_id': "Clingman's Dome (Great Smoky Mountains National Park)", 'count': 1}
# {'_id': 'Fracisville', 'count': 1}
# {'_id': 'Gila Bend (west of)', 'count': 1}
# {'_id': 'Aminpur (India)', 'count': 1}
# {'_id': 'Grand Terrace', 'count': 7}
# {'_id': 'South Ontario', 'count': 1}
# {'_id': 'Dayhoit', 'count': 1}
# {'_id': 'Post Falls', 'count': 26}
# {'_id': 'Erawan (Muang Loei)(Thailand)', 'count': 1}
# {'_id': 'Kailua Kona', 'count': 7}
# {'_id': 'Baltimore County', 'count': 1}
# {'_id': 'Humble/Atascocita', 'count': 1}
# {'_id': 'North Montpelier', 'count': 1}
# {'_id': 'NEW PRAGUE', 'count': 1}
# {'_id': 'Peterborough (UK/England)', 'count': 11}
# {'_id': 'Penrith (UK/England)', 'count': 1}
# {'_id': 'Ashokenagar (India)', 'count': 1}
# {'_id': 'Loma Rica', 'count': 3}
# {'_id': 'Enroute to Michigan', 'count': 1}
# {'_id': 'Algoma', 'count': 4}
# {'_id': 'Woodburn (south of) on I-5 North @mile post 265', 'count': 1}
# {'_id': 'Hollister (southeast of)', 'count': 1}
# {'_id': 'N. Everett', 'count': 1}
# {'_id': 'Brunswick County', 'count': 2}
# {'_id': 'Lower Nazareth', 'count': 1}
# {'_id': 'Green Moontain', 'count': 1}
# {'_id': 'Hillsboro', 'count': 90}
# {'_id': 'Interlaken', 'count': 2}
# {'_id': 'Tonkawa', 'count': 1}
# {'_id': 'Okara (Pakistan)', 'count': 1}
# {'_id': 'Indian Ocean (location unspecified)', 'count': 1}
# {'_id': 'Sydney (Australia', 'count': 1}
# {'_id': 'Rolesville', 'count': 4}
# {'_id': 'Grand Canyon, North Rim', 'count': 1}
# {'_id': 'Syracuse (Elbridge)', 'count': 1}
# {'_id': 'Rayland', 'count': 2}
# {'_id': 'Lexinton', 'count': 2}
# {'_id': 'IndIan Nation Turnpike', 'count': 1}
# {'_id': 'Seattle (Ballard)', 'count': 3}
# {'_id': 'Grenfell (Australia)', 'count': 1}
# {'_id': 'Battle Ground', 'count': 19}
# {'_id': 'Valley View', 'count': 2}
# {'_id': 'Atlantic Ocean (Bermuda Triangle)', 'count': 1}
# {'_id': 'Route 22 bavington exit', 'count': 1}
# {'_id': 'Virginia Beach (City of)', 'count': 1}
# {'_id': 'Imphal (India)', 'count': 1}
# {'_id': 'Camp Pendelton (Oceanside)', 'count': 1}
# {'_id': 'Dawsonville', 'count': 18}
# {'_id': 'Rome (near)', 'count': 1}
# {'_id': 'Mojave Desert (remote area of)', 'count': 1}
# {'_id': 'Pacific Ocean (western)', 'count': 1}
# {'_id': 'Samois sur Seine (France)', 'count': 1}
# {'_id': 'Perrysburg', 'count': 9}
# {'_id': 'Moreno valley', 'count': 1}
# {'_id': 'Fob Shank (Afghanistan)', 'count': 1}
# {'_id': 'Willow Creek', 'count': 4}
# {'_id': 'New Holstein', 'count': 2}
# {'_id': 'Cuchara', 'count': 2}
# {'_id': 'Iselton', 'count': 1}
# {'_id': 'Mono Lake (area)', 'count': 1}
# {'_id': 'Scaley (outside Highlands)', 'count': 1}
# {'_id': 'Montauk', 'count': 9}
# {'_id': 'Caloocan City (Philippines)', 'count': 1}
# {'_id': 'Leigh-on-sea (UK/England)', 'count': 1}
# {'_id': 'Ft. Smith', 'count': 3}
# {'_id': 'San Francisco', 'count': 246}
# {'_id': 'Vila Velha (Brazil)', 'count': 1}
# {'_id': 'Teton Village', 'count': 1}
# {'_id': 'Abilene (near)', 'count': 1}
# {'_id': 'Rowley', 'count': 5}
# {'_id': 'East Brunswick', 'count': 12}
# {'_id': 'South Hempstead', 'count': 1}
# {'_id': 'mill creek', 'count': 1}
# {'_id': 'Rome/Nekoosa', 'count': 1}
# {'_id': 'Bremen (Germany)', 'count': 3}
# {'_id': 'Carolina (Puerto Rico)', 'count': 5}
# {'_id': 'South Ozone Park', 'count': 1}
# {'_id': 'Glen Waverley (Australia)', 'count': 1}
# {'_id': 'Spanish Springs', 'count': 1}
# {'_id': 'Stinnett', 'count': 1}
# {'_id': 'Firebaugh/Mercey Hot Springs', 'count': 1}
# {'_id': 'Haltom City', 'count': 10}
# {'_id': 'Millmont', 'count': 1}
# {'_id': 'Ashland', 'count': 87}
# {'_id': 'Seika-cho (Kyoto Prefecture) (Japan)', 'count': 1}
# {'_id': 'Fort Bayard', 'count': 1}
# {'_id': 'Bulls Gap', 'count': 3}
# {'_id': 'North Kingstown', 'count': 17}
# {'_id': 'Redwood Valley', 'count': 6}
# {'_id': 'Clyde (near)', 'count': 1}
# {'_id': 'Motley/Cottle Counties', 'count': 1}
# {'_id': 'Danbury (near; Carmel VOR)', 'count': 1}
# {'_id': 'Bloomsburg/White haven', 'count': 1}
# {'_id': 'Arkansas (location unknown)', 'count': 1}
# {'_id': 'Tinker AFB', 'count': 2}
# {'_id': 'Ottsville', 'count': 1}
# {'_id': 'Kaneohe', 'count': 15}
# {'_id': 'Munroe Falls', 'count': 2}
# {'_id': 'Cogan Station', 'count': 1}
# {'_id': 'Eglon (Whidbey Island)', 'count': 1}
# {'_id': 'Mexico DF (Mexico)', 'count': 1}
# {'_id': 'Arizona', 'count': 4}
# {'_id': 'Pasquag', 'count': 1}
# {'_id': 'Pittsburgh area', 'count': 1}
# {'_id': 'Nisqually Delta', 'count': 1}
# {'_id': 'Draper', 'count': 14}
# {'_id': 'South Elgin', 'count': 14}
# {'_id': 'San Antonio (ranch outside of)', 'count': 1}
# {'_id': 'Beatty (near)', 'count': 1}
# {'_id': 'Orwigsburg/Deer Lake Area', 'count': 1}
# {'_id': 'Fairdale', 'count': 5}
# {'_id': 'Socal', 'count': 1}
# {'_id': 'Bablyon', 'count': 1}
# {'_id': 'Sioux Lookout (Canada)', 'count': 3}
# {'_id': 'Ramadi (Iraq)', 'count': 2}
# {'_id': 'Multnomah Village', 'count': 1}
# {'_id': 'Lancashire (UK/England)', 'count': 8}
# {'_id': 'Indian Orchard', 'count': 2}
# {'_id': 'Stony Plain & Spruce Grove (Canada)', 'count': 1}
# {'_id': 'Sebring', 'count': 24}
# {'_id': 'Bullock', 'count': 1}
# {'_id': 'Nesbit', 'count': 1}
# {'_id': 'Lodge Grass', 'count': 2}
# {'_id': 'Glade Spring', 'count': 1}
# {'_id': 'League city', 'count': 1}
# {'_id': 'Grass Valley', 'count': 35}
# {'_id': 'Yellowstone', 'count': 1}
# {'_id': 'New Washington', 'count': 7}
# {'_id': 'Crown Point', 'count': 28}
# {'_id': 'Hampton', 'count': 84}
# {'_id': 'Ft. Wayne', 'count': 5}
# {'_id': 'Honokaa', 'count': 2}
# {'_id': 'Slough, Berksire (UK/England)', 'count': 1}
# {'_id': 'Alta Loma', 'count': 7}
# {'_id': 'Trout Creek', 'count': 1}
# {'_id': 'Benton (Aurora)', 'count': 1}
# {'_id': 'Interlochen', 'count': 2}
# {'_id': 'Diyarbak (Turkey)', 'count': 1}
# {'_id': 'Iwakuni (Japan)', 'count': 2}
# {'_id': 'Upper Dublin', 'count': 1}
# {'_id': 'Mccrae', 'count': 1}
# {'_id': 'Alachua County', 'count': 1}
# {'_id': 'Waldport', 'count': 7}
# {'_id': 'Langley Air Force Base', 'count': 1}
# {'_id': 'Cedar Falls', 'count': 20}
# {'_id': 'Moorsville', 'count': 2}
# {'_id': 'Joshua Tree', 'count': 16}
# {'_id': 'Avalon', 'count': 16}
# {'_id': 'Kanab', 'count': 6}
# {'_id': 'Oley', 'count': 5}
# {'_id': 'Orr', 'count': 4}
# {'_id': 'Donalds', 'count': 4}
# {'_id': 'Kettle Point (Canada)', 'count': 1}
# {'_id': 'Cross Village', 'count': 1}
# {'_id': 'Mount vernon', 'count': 1}
# {'_id': 'Mardela springs', 'count': 1}
# {'_id': 'Thassos Island (greece)', 'count': 1}
# {'_id': 'Indian Harbor Beach', 'count': 1}
# {'_id': 'Center Groton', 'count': 1}
# {'_id': 'Rancho Dominguez', 'count': 1}
# {'_id': 'Kolkata (India)', 'count': 4}
# {'_id': 'Tyndall AFB', 'count': 1}
# {'_id': 'Cessy (France)', 'count': 1}
# {'_id': 'Arcade', 'count': 3}
# {'_id': 'North Wayne', 'count': 1}
# {'_id': 'Tofield (rural) (Canada)', 'count': 1}
# {'_id': 'Kentucky (rural)', 'count': 2}
# {'_id': 'Wendover (east of)', 'count': 1}
# {'_id': 'Pico Rivera/Paramount', 'count': 1}
# {'_id': 'Grand Saline', 'count': 2}
# {'_id': 'Chimes', 'count': 1}
# {'_id': 'Highway 71 between Clearmont, Missouri and Maryville, Missou', 'count': 1}
# {'_id': 'Fond du Lac', 'count': 20}
# {'_id': 'Jax Beach', 'count': 1}
# {'_id': 'Park Forest', 'count': 6}
# {'_id': 'East Windsor (Cranbury)', 'count': 1}
# {'_id': 'Saldus (Latvia)', 'count': 1}
# {'_id': 'Breaux Bridge', 'count': 4}
# {'_id': 'Abbeville', 'count': 6}
# {'_id': 'Rotterdam (near) (Netherlands)', 'count': 1}
# {'_id': 'New Fairfield', 'count': 6}
# {'_id': 'McKees Rocks (Kennedy Twp.)', 'count': 1}
# {'_id': 'Salinas Victoria', 'count': 1}
# {'_id': 'Irwindale/Azusa', 'count': 1}
# {'_id': 'In-flight (midwestern U. S.)', 'count': 1}
# {'_id': 'Pinkney', 'count': 2}
# {'_id': 'Landrum', 'count': 1}
# {'_id': 'Baileys Harbor', 'count': 3}
# {'_id': 'Pardeeville', 'count': 2}
# {'_id': 'Shady Side', 'count': 3}
# {'_id': 'E. Parsonsfield', 'count': 1}
# {'_id': 'Pipersville', 'count': 3}
# {'_id': 'Schoolcraft', 'count': 1}
# {'_id': 'Champaign', 'count': 17}
# {'_id': 'Ropar (Punjab)(India)', 'count': 1}
# {'_id': 'Plum Boro', 'count': 1}
# {'_id': 'Pine Lake Leisure Center (Canada)', 'count': 1}
# {'_id': 'Florida (southern)', 'count': 1}
# {'_id': 'Rochester (Kent) (UK/England)', 'count': 1}
# {'_id': 'Emigrant Pass (near; foothills of)', 'count': 1}
# {'_id': 'Bishop', 'count': 14}
# {'_id': 'Bricktown', 'count': 6}
# {'_id': 'Merseyside (UK/England)', 'count': 3}
# {'_id': 'Ste-Justine de Newton (Canada)', 'count': 1}
# {'_id': 'Ottawa (Canada)', 'count': 124}
# {'_id': 'Jalandhar (India)', 'count': 2}
# {'_id': 'Coates', 'count': 1}
# {'_id': 'Scranton/Dunmore', 'count': 1}
# {'_id': 'Mountaindale', 'count': 2}
# {'_id': 'Cambrige', 'count': 1}
# {'_id': 'Walkersville', 'count': 1}
# {'_id': 'In-flight (Georgia)', 'count': 1}
# {'_id': 'Kiel', 'count': 3}
# {'_id': 'Sipoo (Finland)', 'count': 1}
# {'_id': 'Summit Lake Exit, Hwy 42', 'count': 1}
# {'_id': 'Knightstown', 'count': 1}
# {'_id': 'Homestead/Redlands/Everglades', 'count': 1}
# {'_id': 'Fort Mohave', 'count': 7}
# {'_id': 'Xenia Township', 'count': 1}
# {'_id': 'Apache junction', 'count': 1}
# {'_id': 'Indian Rocks', 'count': 1}
# {'_id': 'Carlsbad/Leucaida', 'count': 1}
# {'_id': 'Hume', 'count': 1}
# {'_id': 'Mount Pocono', 'count': 1}
# {'_id': 'Northvale', 'count': 1}
# {'_id': 'Sykia, Halkidiki (Greece)', 'count': 1}
# {'_id': 'Crystal Falls', 'count': 2}
# {'_id': 'McKinney', 'count': 32}
# {'_id': 'Emmett', 'count': 11}
# {'_id': 'Ft. Lauderdale (near coastal)', 'count': 1}
# {'_id': 'Hanover', 'count': 54}
# {'_id': 'Montclair', 'count': 19}
# {'_id': 'Ball Ground', 'count': 11}
# {'_id': 'McCormick', 'count': 3}
# {'_id': 'Rolla', 'count': 27}
# {'_id': 'Stockton on tees (UK/England', 'count': 1}
# {'_id': 'Charlotte Amalie (U. S. Virgin Islands)', 'count': 1}
# {'_id': 'Moriches Bay (Long Island)', 'count': 2}
# {'_id': 'Mt. Shasta (above)', 'count': 1}
# {'_id': 'Sayward (Canada)', 'count': 2}
# {'_id': 'Leeds (UK/England)', 'count': 23}
# {'_id': 'Tunbridge', 'count': 1}
# {'_id': 'St. Louis (Canada)', 'count': 1}
# {'_id': 'Greenfield Center', 'count': 1}
# {'_id': 'Sale Creek', 'count': 3}
# {'_id': 'Colorado (southeast)', 'count': 1}
# {'_id': 'Morehead City', 'count': 9}
# {'_id': 'Venlo (Netherlands)', 'count': 2}
# {'_id': 'Dayton (near )', 'count': 1}
# {'_id': 'Great Sand Dunes National Monument', 'count': 1}
# {'_id': 'Cocolalla', 'count': 1}
# {'_id': 'Laktasi', 'count': 1}
# {'_id': 'Tilene', 'count': 1}
# {'_id': 'Lawton (between Lawton and Duncan, hwy 7 west going east)', 'count': 1}
# {'_id': 'Toronto (Australia)', 'count': 1}
# {'_id': 'Lago Vista', 'count': 8}
# {'_id': 'Polacca', 'count': 2}
# {'_id': 'Minneapolis-Uptown', 'count': 1}
# {'_id': 'Lambton Shores (Canada)', 'count': 1}
# {'_id': 'Joppatown', 'count': 2}
# {'_id': 'Westlake', 'count': 16}
# {'_id': 'Senecaville', 'count': 2}
# {'_id': 'Hartenbos/George (South Africa)', 'count': 1}
# {'_id': 'Zachary', 'count': 4}
# {'_id': 'Brigham City', 'count': 5}
# {'_id': 'Pierce county', 'count': 1}
# {'_id': 'Old Station', 'count': 2}
# {'_id': 'Pierz', 'count': 1}
# {'_id': 'Burrton', 'count': 1}
# {'_id': 'PIco Rivera', 'count': 1}
# {'_id': 'Runcorn (UK/England)', 'count': 2}
# {'_id': 'Tehachapie (outside of)', 'count': 1}
# {'_id': 'Simla', 'count': 3}
# {'_id': 'Gibert/Mesa Border', 'count': 1}
# {'_id': 'Creve Couer', 'count': 1}
# {'_id': 'Bromsgrove (UK/England)', 'count': 1}
# {'_id': 'Blanchardville', 'count': 3}
# {'_id': 'Aurora Siderd (Hwy. 400) (Canada)', 'count': 1}
# {'_id': 'Sugarloaf Mtn.', 'count': 1}
# {'_id': 'Simi valley', 'count': 2}
# {'_id': 'Springer (NM)/Colorado City (CO)', 'count': 1}
# {'_id': 'Soso', 'count': 1}
# {'_id': 'Big Stone Gap', 'count': 3}
# {'_id': 'Portland (southeast of)', 'count': 4}
# {'_id': 'Kimberley (Canada)', 'count': 4}
# {'_id': 'Negril (Jamaica)', 'count': 4}
# {'_id': 'Greenehaven', 'count': 1}
# {'_id': 'Calicut (India)', 'count': 1}
# {'_id': 'Fort Suppy', 'count': 1}
# {'_id': 'Herzliya (Israel)', 'count': 1}
# {'_id': 'Arabian Sea (India)', 'count': 1}
# {'_id': 'Au Sable Forks', 'count': 1}
# {'_id': 'Ingleside', 'count': 8}
# {'_id': 'Tightwad', 'count': 1}
# {'_id': 'Ballston Lake/Malta', 'count': 1}
# {'_id': 'Pigeon Forge', 'count': 13}
# {'_id': 'St. Marys Point', 'count': 1}
# {'_id': 'Tacna (approx)', 'count': 1}
# {'_id': 'West Elkton', 'count': 2}
# {'_id': 'NAS Lemoore', 'count': 1}
# {'_id': 'Seligman (near)', 'count': 1}
# {'_id': 'Barnstable', 'count': 5}
# {'_id': 'Belle Harbor', 'count': 1}
# {'_id': 'Coulee City', 'count': 2}
# {'_id': 'Blue Hill', 'count': 3}
# {'_id': 'Asseteague Island State Park', 'count': 1}
# {'_id': 'Cassadaga', 'count': 2}
# {'_id': 'Regina (Canada', 'count': 1}
# {'_id': 'Yallingup (Western Australia)', 'count': 1}
# {'_id': 'Indy', 'count': 1}
# {'_id': 'Pearl Ridge', 'count': 1}
# {'_id': 'Colchester (Canada)', 'count': 1}
# {'_id': 'Walsenberg', 'count': 1}
# {'_id': 'Miami/keys', 'count': 1}
# {'_id': 'Nevada (on highway, northbound)', 'count': 1}
# {'_id': 'EL Cajon', 'count': 1}
# {'_id': 'Morongo Valley', 'count': 8}
# {'_id': 'Hastings (Canada)', 'count': 2}
# {'_id': 'Montauk (Town of East Hampton)', 'count': 1}
# {'_id': 'Hazelton', 'count': 3}
# {'_id': 'Kauai (2/miles off north coast of)', 'count': 1}
# {'_id': 'South Korea', 'count': 1}
# {'_id': 'Terre Haute (near)', 'count': 1}
# {'_id': 'Peoria County', 'count': 1}
# {'_id': 'Moshiem', 'count': 1}
# {'_id': 'Fort Albany (Canada)', 'count': 1}
# {'_id': 'Melkbosstrand (South Africa)', 'count': 1}
# {'_id': 'Bellington', 'count': 1}
# {'_id': 'Myrtle Creek', 'count': 7}
# {'_id': 'Sylacauga', 'count': 4}
# {'_id': 'Cave Spring', 'count': 3}
# {'_id': 'Murphuys', 'count': 1}
# {'_id': 'Goldsboro (north of)', 'count': 1}
# {'_id': 'SeaTac Airport', 'count': 1}
# {'_id': 'St. Helena', 'count': 2}
# {'_id': 'Graford', 'count': 2}
# {'_id': 'Culpeper County (location unspecified)', 'count': 1}
# {'_id': 'Simco (20-40 km west of) (Canada)', 'count': 1}
# {'_id': 'Richlands', 'count': 7}
# {'_id': 'Lindell Beach (Canada)', 'count': 1}
# {'_id': 'Arizona (northern)', 'count': 1}
# {'_id': 'Highway 24 (near St. Louis)', 'count': 1}
# {'_id': 'San Salvador (El Salvador)', 'count': 1}
# {'_id': 'Oneida', 'count': 8}
# {'_id': 'Walled Lake', 'count': 6}
# {'_id': 'Manchac', 'count': 1}
# {'_id': 'Poughquag', 'count': 5}
# {'_id': 'White Mountains', 'count': 2}
# {'_id': 'St. Amant', 'count': 2}
# {'_id': 'South Kilkenny (Ireland)', 'count': 1}
# {'_id': 'C.B.R.M. (Canada)', 'count': 1}
# {'_id': 'Algodones', 'count': 2}
# {'_id': 'Broken Bow', 'count': 1}
# {'_id': 'Longbranch', 'count': 2}
# {'_id': 'Lindsborg to Lyons', 'count': 1}
# {'_id': 'Kazerin (Israel)', 'count': 1}
# {'_id': 'Schuylerville', 'count': 3}
# {'_id': 'Kings mountain', 'count': 1}
# {'_id': 'Southampton', 'count': 19}
# {'_id': 'Lahore', 'count': 1}
# {'_id': 'Portage la prairie', 'count': 1}
# {'_id': 'Zolfo Springs', 'count': 1}
# {'_id': 'Anacortes and Coupeville', 'count': 1}
# {'_id': 'East Bridgewater', 'count': 4}
# {'_id': 'Indian Rocks beach', 'count': 2}
# {'_id': 'Oakley', 'count': 29}
# {'_id': 'Sicklerviller/Turnersville', 'count': 1}
# {'_id': 'Farwell', 'count': 2}
# {'_id': 'Tracy City', 'count': 1}
# {'_id': 'Keedysville', 'count': 2}
# {'_id': 'Knob Noster', 'count': 2}
# {'_id': 'Turks (and Caicos)', 'count': 1}
# {'_id': 'Osborne', 'count': 1}
# {'_id': 'Oreana', 'count': 1}
# {'_id': 'Weld', 'count': 1}
# {'_id': 'Maces Bay (Canada)', 'count': 1}
# {'_id': 'Miesau (Germany)', 'count': 1}
# {'_id': 'Namur (Belgium)', 'count': 1}
# {'_id': 'Gippsland (Australia)', 'count': 1}
# {'_id': 'Earl Shilton (UK/England)', 'count': 1}
# {'_id': 'Michigan City', 'count': 16}
# {'_id': 'Bear River/Evanston', 'count': 1}
# {'_id': 'Big Horn Mtns', 'count': 1}
# {'_id': 'Starke', 'count': 5}
# {'_id': 'Biddeford Pool', 'count': 1}
# {'_id': 'Naples', 'count': 121}
# {'_id': 'Big Sur', 'count': 10}
# {'_id': 'Port Perry (Canada)', 'count': 4}
# {'_id': 'Skillman', 'count': 1}
# {'_id': 'Guymon', 'count': 1}
# {'_id': 'Havre De Grace', 'count': 1}
# {'_id': 'Asher', 'count': 1}
# {'_id': 'Ile Perrot (Canada)', 'count': 1}
# {'_id': 'Stapleton', 'count': 1}
# {'_id': 'Olmsteadville', 'count': 1}
# {'_id': 'Greenville (Canada)', 'count': 3}
# {'_id': 'Shannon', 'count': 2}
# {'_id': 'Manat (Puerto Rico)', 'count': 1}
# {'_id': 'Holiday/Tarpon Springs', 'count': 1}
# {'_id': 'International waters (Mexico)', 'count': 1}
# {'_id': 'Oklahoma (rural)', 'count': 2}
# {'_id': 'Wellington Lake', 'count': 1}
# {'_id': 'Sydney (west) (NSW, Australia)', 'count': 1}
# {'_id': 'Beebe', 'count': 3}
# {'_id': 'Dushore', 'count': 1}
# {'_id': 'Archdale', 'count': 1}
# {'_id': 'Logan (Western Australia)', 'count': 1}
# {'_id': 'Alberton', 'count': 4}
# {'_id': 'Kinston', 'count': 3}
# {'_id': 'West harrison', 'count': 1}
# {'_id': 'Italy', 'count': 4}
# {'_id': 'Douglas (Isle of Man) (UK/England)', 'count': 2}
# {'_id': 'Norristown', 'count': 13}
# {'_id': 'Northwest', 'count': 1}
# {'_id': 'Conklin', 'count': 1}
# {'_id': 'Winnemucca (West of)', 'count': 1}
# {'_id': 'Red Rock Canyon', 'count': 3}
# {'_id': 'Kaduruwela (Sri Lanka)', 'count': 2}
# {'_id': 'Sea Tac Airport', 'count': 1}
# {'_id': 'Naples (Italy)', 'count': 1}
# {'_id': 'Llanasa (UK/Wales)', 'count': 1}
# {'_id': 'Hubbardston', 'count': 2}
# {'_id': 'Mililani (Oahu/Honolulu)', 'count': 1}
# {'_id': 'Tooele Utah', 'count': 1}
# {'_id': 'Shoreham', 'count': 1}
# {'_id': 'Omemee (Canada)', 'count': 1}
# {'_id': 'Hebe/Klingerstown', 'count': 1}
# {'_id': 'westlake village', 'count': 1}
# {'_id': 'Jerseyville', 'count': 7}
# {'_id': 'Frenchberg', 'count': 1}
# {'_id': 'Williston/ Archer', 'count': 1}
# {'_id': 'Holyoke', 'count': 18}
# {'_id': 'Kouts', 'count': 1}
# {'_id': 'Lexingtob', 'count': 1}
# {'_id': 'Kabetogama', 'count': 1}
# {'_id': 'Algonac', 'count': 6}
# {'_id': 'Polk (south of)', 'count': 1}
# {'_id': 'Topsham', 'count': 3}
# {'_id': 'Highway 5?', 'count': 1}
# {'_id': 'Bonaire', 'count': 2}
# {'_id': 'Tartu (Estonia)', 'count': 2}
# {'_id': 'Honey Harbour (Canada)', 'count': 1}
# {'_id': 'Barneveld', 'count': 4}
# {'_id': 'West Paterson', 'count': 2}
# {'_id': 'Trotwood', 'count': 2}
# {'_id': 'Evansburg (Canada)', 'count': 1}
# {'_id': 'James Island', 'count': 9}
# {'_id': 'Ardonia', 'count': 1}
# {'_id': 'Olivet', 'count': 3}
# {'_id': 'Mears', 'count': 1}
# {'_id': 'Las Americas (Tenerife, Canary Islands)', 'count': 1}
# {'_id': 'Al-Ain (UAE)', 'count': 1}
# {'_id': 'K.maras', 'count': 1}
# {'_id': 'Burl County', 'count': 1}
# {'_id': 'Amesbury', 'count': 9}
# {'_id': 'Lively (Canada)', 'count': 1}
# {'_id': 'Perkinston', 'count': 2}
# {'_id': 'Miami (Suburbs)', 'count': 1}
# {'_id': 'Fort Mcmurray (Canada)', 'count': 1}
# {'_id': 'La Canada Flintridge', 'count': 2}
# {'_id': 'Torrington', 'count': 29}
# {'_id': 'Ipoh (Malaysia)', 'count': 2}
# {'_id': 'Bauxite', 'count': 5}
# {'_id': 'Atlantic City??', 'count': 1}
# {'_id': 'English Bay, Vancouver (Canada)', 'count': 1}
# {'_id': 'Argyll (UK/Scotland)', 'count': 1}
# {'_id': 'Langdon (Canada)', 'count': 1}
# {'_id': 'Sartell', 'count': 7}
# {'_id': 'Alstead', 'count': 2}
# {'_id': 'Green Co.', 'count': 1}
# {'_id': 'Merced County', 'count': 1}
# {'_id': 'Deming (south of)', 'count': 1}
# {'_id': 'Wootton Bridge, Isle of Wight (UK/England)', 'count': 1}
# {'_id': 'Chawton, Hampshire (UK/England)', 'count': 4}
# {'_id': 'North Prairie', 'count': 1}
# {'_id': 'Antarctic', 'count': 1}
# {'_id': 'Wilhoit', 'count': 2}
# {'_id': 'White', 'count': 2}
# {'_id': 'East Elmhurst', 'count': 2}
# {'_id': 'Ireland (city not specified)', 'count': 1}
# {'_id': 'Sullivan (near)', 'count': 1}
# {'_id': 'Chula Vist', 'count': 1}
# {'_id': 'Banff (Canada)', 'count': 4}
# {'_id': 'St. Helen', 'count': 2}
# {'_id': 'Everett', 'count': 168}
# {'_id': 'Moss', 'count': 1}
# {'_id': 'Meadow Creek', 'count': 1}
# {'_id': 'Doerun', 'count': 1}
# {'_id': 'Tonapah', 'count': 2}
# {'_id': 'Efland', 'count': 2}
# {'_id': 'Auburn Lake Park', 'count': 1}
# {'_id': 'Walla Walla Airport', 'count': 1}
# {'_id': 'Rockwood (Somerset)', 'count': 1}
# {'_id': 'Lyme', 'count': 5}
# {'_id': 'St. Ansgar', 'count': 1}
# {'_id': 'Blyth', 'count': 1}
# {'_id': 'Creve Coeur', 'count': 5}
# {'_id': 'Denver DIA', 'count': 1}
# {'_id': 'Mississauga (Toronto) (Canada)', 'count': 1}
# {'_id': 'Wayne', 'count': 40}
# {'_id': 'Pilot Rock', 'count': 6}
# {'_id': 'Chestertown', 'count': 7}
# {'_id': 'Wading River? Franklin Sq', 'count': 1}
# {'_id': 'Magna', 'count': 17}
# {'_id': 'Ouray', 'count': 2}
# {'_id': 'Dubuque', 'count': 26}
# {'_id': 'SSault Ste. Marie (Canada)', 'count': 1}
# {'_id': 'Mountain View', 'count': 29}
# {'_id': 'Cleveland (?)', 'count': 1}
# {'_id': 'Venice', 'count': 71}
# {'_id': 'Bound Brook area', 'count': 1}
# {'_id': 'Tulare (close to, on I-5)', 'count': 1}
# {'_id': 'Kerman (Iran)', 'count': 1}
# {'_id': 'Gunnison (30 Miles NE of)', 'count': 1}
# {'_id': 'Trent Hills (Canada)', 'count': 1}
# {'_id': 'Wolverhampton (UK/England)', 'count': 17}
# {'_id': 'Pontotoc', 'count': 7}
# {'_id': 'Mission viejo', 'count': 1}
# {'_id': 'Soap Lake (Sun Lakes State Park)', 'count': 1}
# {'_id': 'Fonthill (Canada)', 'count': 2}
# {'_id': 'Harkers Island', 'count': 1}
# {'_id': "St. Paul's", 'count': 1}
# {'_id': 'White Mountain', 'count': 1}
# {'_id': 'Bellefonte', 'count': 4}
# {'_id': 'NSA Souda Bay (Greece)', 'count': 1}
# {'_id': 'Nordman', 'count': 1}
# {'_id': 'Alameda Naval Air Station/Marine Corp Air Wing Bubble', 'count': 1}
# {'_id': 'Cross River', 'count': 2}
# {'_id': 'Stahlstown', 'count': 1}
# {'_id': 'Stamford', 'count': 39}
# {'_id': 'Desert Center (near)', 'count': 1}
# {'_id': 'Colburn', 'count': 1}
# {'_id': 'Moram (UK/Scotland)', 'count': 1}
# {'_id': 'Philipsburg', 'count': 11}
# {'_id': 'Grain Valley', 'count': 4}
# {'_id': 'Cromwell (near)', 'count': 1}
# {'_id': 'Honolulu', 'count': 130}
# {'_id': 'Oracle', 'count': 3}
# {'_id': 'Scene in English movie (UK/England)', 'count': 1}
# {'_id': 'Reggae on the River', 'count': 1}
# {'_id': 'Alton (Kendall Hill Subdivision)', 'count': 1}
# {'_id': 'Beechnut/west loop south', 'count': 1}
# {'_id': 'Tramore (Ireland)', 'count': 1}
# {'_id': 'Millen', 'count': 1}
# {'_id': 'rte 9', 'count': 1}
# {'_id': 'Durango', 'count': 20}
# {'_id': 'On the Mass Pike: Rt. 90', 'count': 1}
# {'_id': 'Gold Coast (QLD, Australia)', 'count': 2}
# {'_id': 'Antarctica (Ross Ice shelf) (Antarctica)', 'count': 1}
# {'_id': 'Cumbria (UK/England)', 'count': 2}
# {'_id': 'Cape Lookout', 'count': 1}
# {'_id': 'Mercer', 'count': 7}
# {'_id': 'Hermosillo, Sonora (Mexico)', 'count': 2}
# {'_id': 'NAS Whidby Island/Oak Harbor', 'count': 1}
# {'_id': 'Bingen', 'count': 1}
# {'_id': 'Williams Bay', 'count': 2}
# {'_id': 'Kaiapoi Christchurch (New Zealand)', 'count': 1}
# {'_id': 'Ridgecrest/China Lake', 'count': 2}
# {'_id': 'Hungry Horse', 'count': 2}
# {'_id': 'Nichols', 'count': 1}
# {'_id': 'E. Falmouth', 'count': 2}
# {'_id': 'Jupiter Farms', 'count': 1}
# {'_id': 'Wright City', 'count': 2}
# {'_id': 'Mashhad (Iran)', 'count': 1}
# {'_id': 'Hickory Grove', 'count': 1}
# {'_id': 'Mohawk', 'count': 5}
# {'_id': 'Fairmont', 'count': 14}
# {'_id': 'Santa Ysabel', 'count': 1}
# {'_id': 'Mound House', 'count': 1}
# {'_id': 'White Sand Missile Range - North Ocuro Peak', 'count': 1}
# {'_id': 'Basak Gate Lapu-Lapu City,Cebu (Philippines)', 'count': 1}
# {'_id': 'Thornbury, Bristol UK (England)', 'count': 1}
# {'_id': 'Swan Hills (Canada)', 'count': 1}
# {'_id': 'North Phoenix/Scottsdale', 'count': 1}
# {'_id': 'Orangeville', 'count': 2}
# {'_id': 'LeGrange', 'count': 1}
# {'_id': 'Easten Beach (Gibralter)', 'count': 1}
# {'_id': 'Ohio City', 'count': 1}
# {'_id': 'Morocco (Sidi Yahia U.S. Naval Facility)', 'count': 1}
# {'_id': 'Mecosta', 'count': 1}
# {'_id': 'White Sands National', 'count': 1}
# {'_id': 'Arizona City', 'count': 11}
# {'_id': 'Fortingall', 'count': 1}
# {'_id': 'Delano', 'count': 7}
# {'_id': 'Wexford (Ireland)', 'count': 1}
# {'_id': 'Valley City', 'count': 31}
# {'_id': 'Hammonds Plains (Canada)', 'count': 1}
# {'_id': 'Sedro Woolley (So. of, high in sky)', 'count': 1}
# {'_id': 'Jaworzynka (Poland)', 'count': 1}
# {'_id': 'Baker Lake (rural WA)', 'count': 1}
# {'_id': 'High Point (rural)', 'count': 1}
# {'_id': 'Texhoma', 'count': 2}
# {'_id': 'Prestonsburg', 'count': 5}
# {'_id': 'New Brunswick (unspecified location) (Canada)', 'count': 1}
# {'_id': 'Osceola to Kansas City', 'count': 1}
# {'_id': 'Washington, D.C. (just outside of)', 'count': 1}
# {'_id': 'Valley Springs', 'count': 11}
# {'_id': 'Carizzo Plains National Mounument', 'count': 1}
# {'_id': 'Plant City/Mulberry', 'count': 1}
# {'_id': 'Waldo', 'count': 2}
# {'_id': 'Pincher Creek (Canada)', 'count': 3}
# {'_id': 'Cloverdale (north of)', 'count': 1}
# {'_id': 'San Francisco de Macoris (Dominican Republic)', 'count': 1}
# {'_id': 'Jamul (east of)', 'count': 1}
# {'_id': 'Nodine', 'count': 2}
# {'_id': 'Thompson (Canada)', 'count': 12}
# {'_id': 'Melbourne Beach', 'count': 16}
# {'_id': 'Taiwan', 'count': 1}
# {'_id': 'Two Hills', 'count': 1}
# {'_id': 'Reagan', 'count': 1}
# {'_id': 'Bozeman', 'count': 72}
# {'_id': 'Redlands (heading nw)', 'count': 1}
# {'_id': 'Frazer Township', 'count': 1}
# {'_id': 'Pikesville', 'count': 5}
# {'_id': 'Winnemucca', 'count': 13}
# {'_id': 'Baroda', 'count': 1}
# {'_id': 'Aurora (Canada)', 'count': 5}
# {'_id': 'Stouffville', 'count': 1}
# {'_id': 'Cavalier', 'count': 1}
# {'_id': 'Isabella', 'count': 2}
# {'_id': 'Unspecified location', 'count': 3}
# {'_id': 'Port Jeff Station', 'count': 1}
# {'_id': 'Pointe Claire (Canada)', 'count': 1}
# {'_id': 'Erath', 'count': 1}
# {'_id': 'Ciudad Quesada (Costa Rica)', 'count': 1}
# {'_id': 'Newtown, TAS (Australia)', 'count': 1}
# {'_id': 'Mt Rainier Nat Park, Cougar rock campground', 'count': 1}
# {'_id': 'St. John\x92s (Canada)', 'count': 1}
# {'_id': 'Beatrice (14 mi SW of)', 'count': 1}
# {'_id': 'Wheeling', 'count': 28}
# {'_id': 'Greensburg/Delmont (Between)', 'count': 1}
# {'_id': 'Kresgeville', 'count': 2}
# {'_id': 'London (NE) (UK/England)', 'count': 1}
# {'_id': 'Ramona (NE San Diego)', 'count': 1}
# {'_id': 'Delray', 'count': 1}
# {'_id': 'Glenpool', 'count': 9}
# {'_id': 'Santa Fe/Glorieta', 'count': 1}
# {'_id': 'Zimbabwe', 'count': 1}
# {'_id': 'Northfield Falls', 'count': 3}
# {'_id': 'Eagle Pass', 'count': 8}
# {'_id': 'Hanford Nuclear facility (near)', 'count': 1}
# {'_id': 'San Diego (Cleveland National Forest)', 'count': 1}
# {'_id': 'Kalaloch area (Burl forest)', 'count': 1}
# {'_id': 'Panama City beach,east', 'count': 1}
# {'_id': 'Tehran (Mazandaran Province) (Iran)', 'count': 1}
# {'_id': 'Saint Augustine Beach (nearest)', 'count': 1}
# {'_id': 'Rabun County (unincorporated)', 'count': 1}
# {'_id': 'South Royalton', 'count': 3}
# {'_id': 'Kemptville (Canada)', 'count': 3}
# {'_id': 'Mayfield Hts', 'count': 1}
# {'_id': 'West Virginia (Interstate 81, near PA border)', 'count': 1}
# {'_id': 'Venado Tuerto (Argentina)', 'count': 1}
# {'_id': 'Portland/Hillsboro', 'count': 1}
# {'_id': 'Washington, D.C. (area)', 'count': 2}
# {'_id': 'Napili', 'count': 2}
# {'_id': 'Decaturville', 'count': 2}
# {'_id': 'Holiday Hills', 'count': 1}
# {'_id': 'In-flight/Europe', 'count': 1}
# {'_id': 'Brecon (UK/Wales)', 'count': 1}
# {'_id': 'Mossyrock', 'count': 3}
# {'_id': 'Port Lambton (near Sarnia) (Canada)', 'count': 1}
# {'_id': 'Hendersville', 'count': 1}
# {'_id': 'Anahuac', 'count': 2}
# {'_id': 'Liberec (Czech Republic)', 'count': 1}
# {'_id': 'Romulus (Metro Airport)', 'count': 1}
# {'_id': 'Flintstone', 'count': 1}
# {'_id': 'George (South Africa)', 'count': 1}
# {'_id': 'Avocado Heights', 'count': 1}
# {'_id': 'Keeneyville', 'count': 1}
# {'_id': 'Rumson', 'count': 1}
# {'_id': 'Marathon County', 'count': 1}
# {'_id': "McDermitt (NE of; Lat 42 05'N Lon 117 00'W", 'count': 1}
# {'_id': 'China Spring', 'count': 6}
# {'_id': 'Toluca Lake', 'count': 3}
# {'_id': 'Tsaile', 'count': 2}
# {'_id': 'Dutchtown', 'count': 1}
# {'_id': 'San Isidro', 'count': 2}
# {'_id': 'Bradenton (northeast area of)', 'count': 1}
# {'_id': 'Rainham (UK/England)', 'count': 1}
# {'_id': 'Iowa (unspecified town)', 'count': 1}
# {'_id': 'Watervliet', 'count': 8}
# {'_id': 'Souderton', 'count': 3}
# {'_id': 'Colorado (southeast part)', 'count': 1}
# {'_id': 'Hector', 'count': 3}
# {'_id': 'Nunn', 'count': 1}
# {'_id': 'Vinita', 'count': 1}
# {'_id': 'Elkins', 'count': 11}
# {'_id': 'Anza Borrego Desert', 'count': 1}
# {'_id': 'Fletcher', 'count': 8}
# {'_id': 'Barachi (Bosnia)', 'count': 1}
# {'_id': 'Powers', 'count': 3}
# {'_id': 'Strasbourg (France)', 'count': 1}
# {'_id': 'Huber Heights/Dayton', 'count': 1}
# {'_id': 'New Castle', 'count': 40}
# {'_id': 'Wheatland', 'count': 8}
# {'_id': 'Huntingdon (Cambridgeshire) (UK/England)', 'count': 1}
# {'_id': 'Quantico Marine Base', 'count': 1}
# {'_id': 'Martelle', 'count': 1}
# {'_id': 'Bellmore', 'count': 5}
# {'_id': 'Loma Linda', 'count': 4}
# {'_id': 'Gibraltar (UK; Spain)', 'count': 1}
# {'_id': 'Milbank', 'count': 1}
# {'_id': 'Yankton', 'count': 13}
# {'_id': 'Bliss', 'count': 3}
# {'_id': 'Rocklin/Auburn', 'count': 1}
# {'_id': 'Kossuth', 'count': 1}
# {'_id': 'Perdido Key', 'count': 2}
# {'_id': 'Middle Sackville (Canada)', 'count': 1}
# {'_id': 'Santa Cruz/Loma Prieta (mountains)', 'count': 1}
# {'_id': 'Palampur (India)', 'count': 1}
# {'_id': 'Arizona (location unspecified)', 'count': 1}
# {'_id': 'Kiawah Island', 'count': 5}
# {'_id': 'Dublin (North County) (Republic of Ireland)', 'count': 1}
# {'_id': 'Higgins Lake', 'count': 1}
# {'_id': 'Horn Lake', 'count': 5}
# {'_id': 'Monte Crist', 'count': 1}
# {'_id': 'Dayton (near)', 'count': 1}
# {'_id': 'Kent City', 'count': 2}
# {'_id': 'Mechanicsburg (near)', 'count': 1}
# {'_id': 'Greenwich Township', 'count': 1}
# {'_id': 'Woodbury', 'count': 45}
# {'_id': 'Belington', 'count': 1}
# {'_id': 'Homer City', 'count': 2}
# {'_id': 'Upper Ssaddle River', 'count': 1}
# {'_id': 'Sharron (Canada)', 'count': 1}
# {'_id': 'La Farge', 'count': 3}
# {'_id': 'Spin Buldak', 'count': 1}
# {'_id': 'Kelsterbach (Germany)', 'count': 2}
# {'_id': 'Newell', 'count': 2}
# {'_id': 'Three Points (Kitt Peak Observatory)', 'count': 1}
# {'_id': 'Brentwood/Maplewood', 'count': 1}
# {'_id': 'New Port Richey, Florida', 'count': 1}
# {'_id': 'Recife', 'count': 1}
# {'_id': 'Diablo Lake (near Ross Lake)', 'count': 1}
# {'_id': 'Piñon Hills', 'count': 1}
# {'_id': 'Quebec City (Canada)', 'count': 7}
# {'_id': 'Hobbs', 'count': 15}
# {'_id': 'Pla (Philippines)', 'count': 1}
# {'_id': 'Airmont', 'count': 1}
# {'_id': 'Hiawatha/Cedar Rapids', 'count': 1}
# {'_id': 'Glen Spey', 'count': 1}
# {'_id': 'Independent Hill', 'count': 2}
# {'_id': 'Erfurt (Thuringia, Germany)', 'count': 1}
# {'_id': 'Ozamiz City, philis (Philippines)', 'count': 1}
# {'_id': 'Notre-Dame du Nord (Canada)', 'count': 1}
# {'_id': 'Beaver Dams', 'count': 1}
# {'_id': 'Mount Laurel', 'count': 12}
# {'_id': 'Dunn', 'count': 7}
# {'_id': 'France', 'count': 4}
# {'_id': 'Northeast', 'count': 1}
# {'_id': 'Tatum', 'count': 5}
# {'_id': 'Ft. Lewis', 'count': 1}
# {'_id': 'Winston-Salem (S of; around Tyro?)', 'count': 1}
# {'_id': 'Aventura', 'count': 10}
# {'_id': 'Israel', 'count': 3}
# {'_id': 'Nauju Lazu village (Lithuania)', 'count': 1}
# {'_id': 'Akron (Ellet)', 'count': 1}
# {'_id': 'Nanaimo', 'count': 1}
# {'_id': 'Clancy', 'count': 2}
# {'_id': 'White Bluff', 'count': 1}
# {'_id': 'Manitoulin Island (Canada)', 'count': 2}
# {'_id': 'Bellefontaine (St. Louis County)', 'count': 1}
# {'_id': 'St. Albans', 'count': 15}
# {'_id': 'Selangor (Malaysia)', 'count': 3}
# {'_id': 'Germany or Holland (from bomber)', 'count': 1}
# {'_id': 'Evans City', 'count': 4}
# {'_id': 'Aokville (Canada)', 'count': 1}
# {'_id': 'Arcata', 'count': 16}
# {'_id': 'Brookpark', 'count': 2}
# {'_id': 'Fajardo (Puerto Rico)', 'count': 2}
# {'_id': 'Bude (UK/England)', 'count': 1}
# {'_id': 'Northamptonshire (UK/England)', 'count': 2}
# {'_id': 'Wurtsboro', 'count': 1}
# {'_id': 'Longwood/Lake Mary', 'count': 1}
# {'_id': 'Nhlangano (Swaziland)', 'count': 1}
# {'_id': 'Southern Pines', 'count': 5}
# {'_id': 'Doolin (Ireland)', 'count': 1}
# {'_id': 'Spokane (Spokane River; Muncies Marina)', 'count': 1}
# {'_id': 'East Barre', 'count': 3}
# {'_id': 'Deep River', 'count': 2}
# {'_id': 'Berthoud', 'count': 6}
# {'_id': 'Hockessin', 'count': 7}
# {'_id': 'Wailea, Maui', 'count': 1}
# {'_id': 'Ellicott City/Oella Mills', 'count': 1}
# {'_id': 'Orland/Tinley Park', 'count': 2}
# {'_id': 'Sioux Falls (near)', 'count': 1}
# {'_id': 'Wiaheke Island (New Zealand)', 'count': 1}
# {'_id': 'Alicante (Spain)', 'count': 2}
# {'_id': 'Augustine (at)', 'count': 1}
# {'_id': 'Playa del Carmen', 'count': 1}
# {'_id': 'Vanderbilt', 'count': 4}
# {'_id': 'Sayville/Blue Point (general area)', 'count': 1}
# {'_id': 'Tuckerton', 'count': 7}
# {'_id': 'Echo', 'count': 1}
# {'_id': 'Gaithersburg/North Potomac', 'count': 1}
# {'_id': 'Timberline Lodge/Mt Hood', 'count': 1}
# {'_id': 'Surpriswe', 'count': 1}
# {'_id': 'Comfort', 'count': 7}
# {'_id': 'Ft. Carson (near); I-25 south', 'count': 1}
# {'_id': 'Miami Gardens', 'count': 2}
# {'_id': 'Mayland', 'count': 2}
# {'_id': 'Dunedin', 'count': 22}
# {'_id': 'Sofia (Bulgaria)', 'count': 9}
# {'_id': 'St. Andrews (Canada)', 'count': 4}
# {'_id': 'Waitsburg', 'count': 1}
# {'_id': "Couer d'alene (south of)", 'count': 1}
# {'_id': 'Riva', 'count': 2}
# {'_id': 'Grand Junction (west of)', 'count': 1}
# {'_id': 'Madison-Clinton', 'count': 1}
# {'_id': 'Nassau (Long Island)', 'count': 1}
# {'_id': 'Merrimack', 'count': 21}
# {'_id': 'Aspen', 'count': 5}
# {'_id': 'none-Frenchman Coulee Gorge', 'count': 1}
# {'_id': 'Colbinstown (Ireland)', 'count': 1}
# {'_id': 'Zhujiang (Newtown; Guangzhou)(China)', 'count': 1}
# {'_id': 'Hardyston Township', 'count': 1}
# {'_id': 'Cape San Blas', 'count': 3}
# {'_id': 'South Park', 'count': 3}
# {'_id': 'Brush Prairie', 'count': 4}
# {'_id': 'Cole Camp', 'count': 2}
# {'_id': 'Robertsbridge', 'count': 1}
# {'_id': 'Greenwood', 'count': 57}
# {'_id': 'Ormond Beach', 'count': 29}
# {'_id': 'Hicksvllie', 'count': 1}
# {'_id': "Couer d'Alene", 'count': 2}
# {'_id': 'Thodupuzha (India)', 'count': 1}
# {'_id': 'Yatesville', 'count': 1}
# {'_id': 'Winnisquam', 'count': 1}
# {'_id': 'Basingstoke (Hampshire)(UK/England)', 'count': 1}
# {'_id': 'Hillsborough, NJ', 'count': 1}
# {'_id': 'Slades Corners', 'count': 1}
# {'_id': 'Markle', 'count': 2}
# {'_id': 'Carlbad', 'count': 1}
# {'_id': 'Stellarton (Canada)', 'count': 1}
# {'_id': 'Cleveland (approaching)', 'count': 1}
# {'_id': 'Potsdam', 'count': 7}
# {'_id': 'White Sulphur Springs', 'count': 6}
# {'_id': 'Clines Corners (I-40 Eastbound)', 'count': 1}
# {'_id': 'Low Moor', 'count': 1}
# {'_id': 'Soperton', 'count': 1}
# {'_id': 'Foxboro (Canada)', 'count': 1}
# {'_id': 'Skelmersdale, Lancashire (UK/England)', 'count': 1}
# {'_id': 'Fort Detrick', 'count': 1}
# {'_id': 'White Hall', 'count': 6}
# {'_id': 'Springfield', 'count': 358}
# {'_id': 'Cardigan (UK/Wales)', 'count': 1}
# {'_id': 'Greesnboro', 'count': 1}
# {'_id': 'Tome', 'count': 2}
# {'_id': 'Stevenage, Herts (UK/England)', 'count': 1}
# {'_id': 'Berwyn', 'count': 10}
# {'_id': 'Jacobstown', 'count': 1}
# {'_id': 'Los Montoyas', 'count': 1}
# {'_id': 'Linwood', 'count': 6}
# {'_id': 'Phoenix and Saguaro Lake', 'count': 1}
# {'_id': 'Lac du Bonnet (Canada)', 'count': 1}
# {'_id': 'Villa Rica', 'count': 17}
# {'_id': 'Rancho', 'count': 1}
# {'_id': 'Morrice (near)', 'count': 1}
# {'_id': 'Viet Nam (jungles of)', 'count': 1}
# {'_id': 'Golqnovci (Bulgaria)', 'count': 1}
# {'_id': 'Sonoma (near)', 'count': 1}
# {'_id': 'Ardmore', 'count': 19}
# {'_id': 'Smiths Cove (Canada)', 'count': 1}
# {'_id': 'Davao (Philippines)', 'count': 1}
# {'_id': 'Lakehills', 'count': 4}
# {'_id': 'North Hero', 'count': 2}
# {'_id': 'South Hiram', 'count': 1}
# {'_id': 'Cranbury', 'count': 2}
# {'_id': 'Columbus, Ohio and surrounding areas', 'count': 1}
# {'_id': 'Meadow Creek (Canada)', 'count': 1}
# {'_id': 'Clackamas (south of)', 'count': 1}
# {'_id': 'Chapeau (Canada)', 'count': 1}
# {'_id': 'Bullhead City/Phoenix (between)', 'count': 1}
# {'_id': 'Sisters (near)', 'count': 1}
# {'_id': 'Hazel Park', 'count': 5}
# {'_id': 'Errol', 'count': 1}
# {'_id': 'Porto Marina Beach', 'count': 1}
# {'_id': 'Hillsboro/Portland', 'count': 1}
# {'_id': 'Whites Lake (Canada)', 'count': 1}
# {'_id': 'Jellico', 'count': 4}
# {'_id': 'Cyprus (Mediterranean Sea)', 'count': 2}
# {'_id': 'Lanley (Canada)', 'count': 1}
# {'_id': 'Buckeye Lake', 'count': 1}
# {'_id': 'Grayridge (outside of; 1/2 mile S.)', 'count': 1}
# {'_id': 'Hermann', 'count': 6}
# {'_id': 'Monroe City', 'count': 5}
# {'_id': 'Saint-John (Canada)', 'count': 1}
# {'_id': 'Princeton/Evansville', 'count': 1}
# {'_id': 'Celo', 'count': 1}
# {'_id': 'Jarabacoa (Dominican Republic)', 'count': 2}
# {'_id': 'Kulnura (Australia)', 'count': 1}
# {'_id': 'Myrtle Beach, Horry County South Carolina', 'count': 1}
# {'_id': 'National Park', 'count': 2}
# {'_id': 'Lapel', 'count': 1}
# {'_id': 'Camp Verde (south of)', 'count': 1}
# {'_id': 'Unincorporated Grayslake/Volo/Wauconda', 'count': 1}
# {'_id': 'Alaska airspace (above Arctic Circle)', 'count': 1}
# {'_id': 'Maracay (Urbaniz, el Castaño) (Venezuela)', 'count': 1}
# {'_id': 'Bruneau/Mountain Home (between)', 'count': 1}
# {'_id': 'Cleveland (Northern)', 'count': 1}
# {'_id': 'Barefoot Bay', 'count': 2}
# {'_id': 'River Falls/Prescott (between)', 'count': 1}
# {'_id': 'Greencastle PA', 'count': 1}
# {'_id': 'New Baden', 'count': 1}
# {'_id': 'Meridian Navel Air Station', 'count': 1}
# {'_id': 'Lower Haines City', 'count': 1}
# {'_id': 'Sand Springs (15-20mi. E/SE of)', 'count': 1}
# {'_id': 'Maumelle', 'count': 5}
# {'_id': 'Cozumel (Mexico)', 'count': 5}
# {'_id': 'Den Haag (Netherlands)', 'count': 1}
# {'_id': 'Boulder (near)', 'count': 1}
# {'_id': 'Kilkenny (Republic of Ireland)', 'count': 2}
# {'_id': 'Marshallville', 'count': 1}
# {'_id': 'Northern Alberta (Canada)', 'count': 1}
# {'_id': 'California desert', 'count': 1}
# {'_id': 'Bejuma, Edo. Carabobo, Caracas (Venezuela)', 'count': 1}
# {'_id': 'Kulpmount', 'count': 1}
# {'_id': 'Olds (Canada)', 'count': 3}
# {'_id': 'Old River-Winfree', 'count': 1}
# {'_id': 'Brandford', 'count': 1}
# {'_id': 'Silverthorn', 'count': 1}
# {'_id': 'Woods Canyon Lake', 'count': 1}
# {'_id': 'Montréal (Canada)', 'count': 2}
# {'_id': 'Walnutport', 'count': 1}
# {'_id': 'Corona/Riverside', 'count': 1}
# {'_id': 'Carson', 'count': 22}
# {'_id': 'North Hardeeville', 'count': 1}
# {'_id': 'Clendenin', 'count': 2}
# {'_id': 'Tuscaloosa', 'count': 24}
# {'_id': 'Romeoville', 'count': 7}
# {'_id': 'Englewood Cliffs', 'count': 3}
# {'_id': 'Denver (50 miles east of) on Interstate 76', 'count': 1}
# {'_id': 'Obrien', 'count': 1}
# {'_id': 'Gillingham', 'count': 2}
# {'_id': 'Manassas', 'count': 40}
# {'_id': 'Ingleside (Canada)', 'count': 2}
# {'_id': 'Capitol heights', 'count': 1}
# {'_id': 'Atmore', 'count': 3}
# {'_id': 'Townsville, Queensland (Australia)', 'count': 1}
# {'_id': 'Lugano (Switzerland)', 'count': 1}
# {'_id': 'Huntinton', 'count': 1}
# {'_id': 'St. Louis (Creve Couer)', 'count': 1}
# {'_id': 'Chadwell St Mary (UK/England)', 'count': 1}
# {'_id': 'Real County', 'count': 1}
# {'_id': 'ForestPark', 'count': 1}
# {'_id': 'Okinawa', 'count': 1}
# {'_id': 'West Pittston', 'count': 1}
# {'_id': 'Exira', 'count': 1}
# {'_id': 'Clearwater', 'count': 73}
# {'_id': 'Richmond Heights', 'count': 3}
# {'_id': 'Mancos', 'count': 1}
# {'_id': 'Audubon', 'count': 8}
# {'_id': 'Whitchurch (Buckinghamshire) (UK/England)', 'count': 1}
# {'_id': 'At Taif (Saudi Arabia)', 'count': 1}
# {'_id': 'Henniker', 'count': 3}
# {'_id': 'Bangalore (India)', 'count': 28}
# {'_id': 'Hiway 27 and the 6th (Canada)', 'count': 1}
# {'_id': 'Calumet City', 'count': 3}
# {'_id': 'Cumberland/Ravensdale', 'count': 1}
# {'_id': 'Petrified Forest (near; on I-40)', 'count': 1}
# {'_id': 'Cieneguilla (Peru)', 'count': 1}
# {'_id': 'Boneta', 'count': 1}
# {'_id': 'Kenvil', 'count': 1}
# {'_id': 'Nurnberg (Germany)', 'count': 1}
# {'_id': 'Byram', 'count': 4}
# {'_id': 'New York City (Bronx, Riverdale)', 'count': 1}
# {'_id': 'Storden', 'count': 1}
# {'_id': 'Parksley', 'count': 2}
# {'_id': 'Port Charlotte', 'count': 52}
# {'_id': 'Cartago', 'count': 1}
# {'_id': 'Springfield/Longmeadow', 'count': 1}
# {'_id': 'lakehills', 'count': 1}
# {'_id': 'Menlo Park', 'count': 1}
# {'_id': 'Danvers', 'count': 12}
# {'_id': 'Larned', 'count': 3}
# {'_id': 'Proctor', 'count': 4}
# {'_id': 'Russellville/Dover', 'count': 1}
# {'_id': 'Vancouver (watching from field at barn)', 'count': 1}
# {'_id': 'Tompson', 'count': 1}
# {'_id': 'West Bowmanstown', 'count': 1}
# {'_id': 'Elk Neck', 'count': 1}
# {'_id': 'Lyman', 'count': 9}
# {'_id': 'Belchertown', 'count': 7}
# {'_id': 'Bayboro', 'count': 1}
# {'_id': 'Eau Gallie', 'count': 1}
# {'_id': 'Madison Lake', 'count': 1}
# ...
# {'_id': 'Buenos Aires (Argentina)', 'count': 11}
# {'_id': 'Inkster', 'count': 4}
# {'_id': 'Yacolt', 'count': 6}
# {'_id': 'Burney', 'count': 7}
# {'_id': 'Interstate 10 (between BR and Laf)', 'count': 1}
# {'_id': 'New Canaan', 'count': 4}
# {'_id': 'Picture Rocks', 'count': 1}
# {'_id': 'Maidsville', 'count': 1}
# {'_id': 'Luguna Woods', 'count': 1}
# {'_id': 'New York City/Far Rockaway', 'count': 1}
# {'_id': 'Bethleham', 'count': 1}
# {'_id': 'Red Lodge', 'count': 7}
# {'_id': 'Centreville (Bib Gish Lake)', 'count': 1}
# {'_id': 'Cardiff (Canada)', 'count': 2}
# {'_id': '((unspecified by witness))', 'count': 1}
# {'_id': 'Ormond Beach/Daytona Beach', 'count': 1}
# {'_id': 'Pocasset (6 miles south of, on Hwy 81)', 'count': 1}
# {'_id': 'Lytham St Annes (UK/England)', 'count': 1}
# {'_id': 'Plaistow', 'count': 3}
# {'_id': 'Sautee', 'count': 1}
# {'_id': 'Oceanside (Orange Co.)(Riverside)', 'count': 1}
# {'_id': 'Mapillville', 'count': 1}
# {'_id': 'Caicara (Venezuela)', 'count': 1}
# {'_id': 'Boilgee', 'count': 1}
# {'_id': 'Catalina Island', 'count': 4}
# {'_id': 'Midlothian', 'count': 34}
# {'_id': 'Baldwin City', 'count': 2}
# {'_id': 'Fairport', 'count': 12}
# {'_id': 'Nickerson State Park. Brewster', 'count': 1}
# {'_id': 'Stoner (Canada)', 'count': 2}
# {'_id': 'Bethalto', 'count': 4}
# {'_id': 'Chestnut Hill', 'count': 2}
# {'_id': 'Puerto de Mazarron (Spain)', 'count': 2}
# {'_id': 'Rochester (MN)/to LaCrosse (WI) (driving)', 'count': 1}
# {'_id': 'Hickory (hwy 321 8mi s.)', 'count': 1}
# {'_id': 'Shreveport (Arcadia)', 'count': 1}
# {'_id': 'Black Mesa/Shonto', 'count': 1}
# {'_id': 'Chattahoochee County', 'count': 1}
# {'_id': 'Seattle to Tokyo (2 NWA flt 007)', 'count': 1}
# {'_id': 'Dayton,Trotwood,West Carrollton', 'count': 1}
# {'_id': 'Pagosa Springs', 'count': 6}
# {'_id': 'Albay (Philippines)', 'count': 1}
# {'_id': 'Kent County (Canada)', 'count': 1}
# {'_id': 'Hortense', 'count': 4}
# {'_id': 'Kansas City\\Lenexa, Kansas area', 'count': 1}
# {'_id': 'Cut Off', 'count': 5}
# {'_id': 'Collingwood/Orangeviille (between) (Canada)', 'count': 1}
# {'_id': 'Alhambra Golf Course', 'count': 1}
# {'_id': 'Ferndale (near, countryside)', 'count': 1}
# {'_id': 'Edroy', 'count': 1}
# {'_id': 'Los Angeles Area', 'count': 1}
# {'_id': 'Tira (Israel; central area)', 'count': 1}
# {'_id': 'Coeymans', 'count': 1}
# {'_id': 'Ithaca/Dansville/Batavia/Weedsport', 'count': 1}
# {'_id': 'Cornwall (South Stormont) (Canada)', 'count': 1}
# {'_id': 'Yosemite Forest (Yosemite Valley)', 'count': 1}
# {'_id': 'Custer', 'count': 9}
# {'_id': 'Pioneer Town', 'count': 1}
# {'_id': 'Longmont (south of)', 'count': 1}
# {'_id': 'Atlantic Ocean/Caribbean sea', 'count': 1}
# {'_id': 'Center Line', 'count': 2}
# {'_id': 'Scottdale', 'count': 6}
# {'_id': 'Bridgeport (Twin Lakes)', 'count': 1}
# {'_id': 'Rapid City (Ellsworth AFB)', 'count': 2}
# {'_id': 'Okemos', 'count': 4}
# {'_id': 'Southwest UK (UK/England)', 'count': 1}
# {'_id': 'Bound Brook', 'count': 2}
# {'_id': 'New Hampshire (rural)', 'count': 1}
# {'_id': 'Wisconsin (rural)', 'count': 1}
# {'_id': 'Stockton (South of)', 'count': 1}
# {'_id': 'Spencerport', 'count': 6}
# {'_id': 'Hunt', 'count': 1}
# {'_id': 'Portsmouth (UK/England)', 'count': 9}
# {'_id': 'Burton on Trent (UK/England)', 'count': 1}
# {'_id': 'Tracadie-Sheila (Canada)', 'count': 1}
# {'_id': 'Fowleville', 'count': 1}
# {'_id': 'Tlaltenango (Mexico)', 'count': 2}
# {'_id': 'Gourock (UK/Scotland)', 'count': 1}
# {'_id': 'Killawog', 'count': 2}
# {'_id': 'Rutherfordton/Outer Gilkey', 'count': 1}
# {'_id': 'Ocala National Forest', 'count': 1}
# {'_id': 'East Lyme', 'count': 1}
# {'_id': 'Estherville', 'count': 1}
# {'_id': 'In-flight (military)(city not specified)', 'count': 1}
# {'_id': 'Avon/Rushford', 'count': 1}
# {'_id': 'Elizabethtown (north of)', 'count': 1}
# {'_id': 'Staffordshire (UK/England)', 'count': 1}
# {'_id': 'Chiclana (Spain)', 'count': 1}
# {'_id': 'Pecks Pond', 'count': 1}
# {'_id': 'Stonefort', 'count': 2}
# {'_id': 'Dodge City', 'count': 9}
# {'_id': 'Cullman', 'count': 17}
# {'_id': 'Knights Ferry', 'count': 1}
# {'_id': 'Oak Hill', 'count': 12}
# {'_id': 'Gibraltar (Mediterranean Sea)', 'count': 1}
# {'_id': 'Spring Mills', 'count': 1}
# {'_id': 'Albany (maybe New York)', 'count': 1}
# {'_id': 'Southport (UK/England)', 'count': 4}
# {'_id': 'Lytham St. Annes (UK/England)', 'count': 1}
# {'_id': 'Yerington', 'count': 7}
# {'_id': 'Carnation', 'count': 8}
# {'_id': 'Trion', 'count': 4}
# {'_id': 'Wascott', 'count': 1}
# {'_id': 'N FL; S GA', 'count': 1}
# {'_id': 'Tuskegee National Forest @ HWY 85', 'count': 1}
# {'_id': 'Llanelli (UK/England)', 'count': 1}
# {'_id': 'New York/San Francisco (flight between)', 'count': 1}
# {'_id': 'Scott AFB/Centralia (between)', 'count': 1}
# {'_id': 'Enders', 'count': 1}
# {'_id': 'Belmont (Canada)', 'count': 2}
# {'_id': 'Bentleyville (3-5 miles east of; on I-70)', 'count': 1}
# {'_id': 'Framington', 'count': 1}
# {'_id': 'Machesney park', 'count': 1}
# {'_id': 'Pharisburg', 'count': 1}
# {'_id': 'West Riffa (Kingdom of Bahrain)', 'count': 1}
# {'_id': 'Polpero, Cornwall (UK/England)', 'count': 1}
# {'_id': 'Pangburn/Searcy', 'count': 1}
# {'_id': 'Nottingham (UK/England)', 'count': 35}
# {'_id': 'Trimley St. Mary (UK/England)', 'count': 1}
# {'_id': 'Yosemite Pass (In the valley over; nr. NV border)', 'count': 1}
# {'_id': 'Hanau (Germany)', 'count': 1}
# {'_id': 'Green Mountain', 'count': 3}
# {'_id': 'Woodcliff Lake', 'count': 2}
# {'_id': 'Koh Samui (Thailand)', 'count': 5}
# {'_id': 'Gulf Mills', 'count': 1}
# {'_id': 'antelope', 'count': 1}
# {'_id': 'Falun', 'count': 1}
# {'_id': 'Brighton Plantation', 'count': 1}
# {'_id': 'Kohila (Estonia)', 'count': 1}
# {'_id': 'St. Helier, Jersey (Channel Islands) (UK/England)', 'count': 1}
# {'_id': 'Pickerington', 'count': 13}
# {'_id': 'Wauseon', 'count': 3}
# {'_id': 'East Yorkshire (UK/England)', 'count': 1}
# {'_id': 'Hotchkiss', 'count': 1}
# {'_id': 'Kettering (UK/England)', 'count': 3}
# {'_id': 'Oak Point', 'count': 2}
# {'_id': 'San Diego (ranch environment)', 'count': 1}
# {'_id': 'Lackawanna County', 'count': 1}
# {'_id': 'DeKabe', 'count': 1}
# {'_id': 'Seagrove Beach (Walton county)', 'count': 1}
# {'_id': 'Current', 'count': 1}
# {'_id': 'Duncansville', 'count': 4}
# {'_id': 'Martins Creek', 'count': 1}
# {'_id': 'Whiting', 'count': 6}
# {'_id': 'Warwick/Coventry', 'count': 1}
# {'_id': 'Tacoma Washington', 'count': 1}
# {'_id': 'Skelmersdale (UK/England)', 'count': 3}
# {'_id': 'Chesapeake Bay Bridge', 'count': 1}
# {'_id': 'Siesta Key', 'count': 8}
# {'_id': 'Coffman Cove', 'count': 1}
# {'_id': 'Roswell (NO JOKE)', 'count': 1}
# {'_id': 'Abbott', 'count': 1}
# {'_id': 'Fancy Gap Mtn. (near; I-77 )', 'count': 1}
# {'_id': 'Oglesby', 'count': 1}
# {'_id': 'Corona del Mar', 'count': 6}
# {'_id': 'Viet Nam', 'count': 5}
# {'_id': 'Sunnyside (Granger, on Hwy 82)', 'count': 1}
# {'_id': 'Wiltshire (UK/England)', 'count': 3}
# {'_id': 'Bensheim (Germany)', 'count': 1}
# {'_id': 'Port Mansfield', 'count': 1}
# {'_id': 'Lancaster County', 'count': 2}
# {'_id': 'Middlesex', 'count': 12}
# {'_id': 'North Aurora', 'count': 4}
# {'_id': 'Menomonee Falls', 'count': 10}
# {'_id': 'Rowve', 'count': 1}
# {'_id': 'Centerview', 'count': 1}
# {'_id': 'Big Falls', 'count': 1}
# {'_id': 'Stewartstown', 'count': 7}
# {'_id': 'Los Lunas/Albuqerque', 'count': 1}
# {'_id': 'Somers', 'count': 11}
# {'_id': 'Seward', 'count': 10}
# {'_id': 'Egg Harbor Twp', 'count': 1}
# {'_id': 'Klerksdorp (South Africa)', 'count': 1}
# {'_id': 'Mediterranean Sea (in flight)', 'count': 1}
# {'_id': 'St. Labre (Canada)', 'count': 1}
# {'_id': 'El Reno', 'count': 9}
# {'_id': 'Australia (northeast)', 'count': 1}
# {'_id': 'Vestal', 'count': 13}
# {'_id': 'Granton', 'count': 4}
# {'_id': 'Bryant Creek, Rippe access', 'count': 1}
# {'_id': 'Milano (Italy)', 'count': 1}
# {'_id': 'Polonnaruwa (Sri Lanka)', 'count': 4}
# {'_id': 'Moclips', 'count': 1}
# {'_id': 'Kayseri (Turkey)', 'count': 1}
# {'_id': 'Vallenar/La Serena (between)', 'count': 1}
# {'_id': 'Duluth', 'count': 88}
# {'_id': 'Kingsley', 'count': 1}
# {'_id': 'Estcourt (South Africa)', 'count': 1}
# {'_id': 'Medicine park', 'count': 1}
# {'_id': 'Dunstable (UK/England)', 'count': 11}
# {'_id': 'Scott AFB (outside of)', 'count': 1}
# {'_id': 'Kawartha Lakes (Canada)', 'count': 2}
# {'_id': 'Pitlochry (UK/Scotland)', 'count': 1}
# {'_id': 'China Spring (or surrounding communities)', 'count': 1}
# {'_id': 'Cos Cob', 'count': 1}
# {'_id': 'Nespelem', 'count': 1}
# {'_id': 'Lake Pleasant', 'count': 2}
# {'_id': 'Indiahoma', 'count': 1}
# {'_id': 'Reverside', 'count': 1}
# {'_id': 'Undisclosed', 'count': 1}
# {'_id': 'Big Kandiyohi Lake', 'count': 1}
# {'_id': 'St-Bruno (Canada)', 'count': 2}
# {'_id': 'Lake Wataree', 'count': 1}
# {'_id': 'Naha (Japan)', 'count': 1}
# {'_id': 'Rennes (France)', 'count': 3}
# {'_id': 'Corrolejo (Fuerteventura) (Canary Islands)', 'count': 1}
# {'_id': 'Trumansburg', 'count': 3}
# {'_id': 'Alabama', 'count': 1}
# {'_id': 'Ein Gedi (Israel)', 'count': 1}
# {'_id': 'Rome', 'count': 44}
# {'_id': 'Key West', 'count': 24}
# {'_id': 'Ilkeston', 'count': 1}
# {'_id': 'Adriatic (Italy/Greece)', 'count': 1}
# {'_id': 'Wood Lake', 'count': 1}
# {'_id': 'Colombia', 'count': 1}
# {'_id': 'Biesenthal (Germany)', 'count': 1}
# {'_id': 'Alpena (near)', 'count': 1}
# {'_id': 'Agusta', 'count': 1}
# {'_id': 'Seeley Lake', 'count': 3}
# {'_id': 'River Pines', 'count': 1}
# {'_id': 'East Windsor', 'count': 8}
# {'_id': 'Goodspring', 'count': 1}
# {'_id': 'Rhinebeck', 'count': 6}
# {'_id': 'Field Store', 'count': 1}
# {'_id': 'Slavonski Brod (Croatia)', 'count': 1}
# {'_id': 'Yakima Indian Reservation', 'count': 1}
# {'_id': 'Heacham (UK/England)', 'count': 1}
# {'_id': 'North Rim', 'count': 1}
# {'_id': 'Cornish', 'count': 4}
# {'_id': 'Doniphan', 'count': 5}
# {'_id': 'Los Angeles/Angeles Natl. Forest', 'count': 1}
# {'_id': 'Cougar', 'count': 4}
# {'_id': 'Hanksville', 'count': 1}
# {'_id': 'Nizhny Novgorod (Russia)', 'count': 1}
# {'_id': 'Blachly', 'count': 1}
# {'_id': 'San Elizario', 'count': 1}
# {'_id': 'Buccaneer Archipelago. W. Australia (Australia)', 'count': 1}
# {'_id': 'Solana Beach', 'count': 3}
# {'_id': 'Green River (20 miles west of on I-70)', 'count': 1}
# {'_id': 'Chicago/Mt. Greenwood', 'count': 1}
# {'_id': 'Jamesville', 'count': 3}
# {'_id': 'Fort Fisher', 'count': 3}
# {'_id': 'Clifford', 'count': 1}
# {'_id': 'Wilkesboro/DeepGap', 'count': 1}
# {'_id': 'Geneva On Lake', 'count': 1}
# {'_id': 'Idaho Springs', 'count': 3}
# {'_id': 'La Pryor', 'count': 1}
# {'_id': 'Eglin AFB', 'count': 3}
# {'_id': 'Wapakoneta', 'count': 8}
# {'_id': 'South China (Three Mile Pond)', 'count': 1}
# {'_id': 'Speedwell', 'count': 3}
# {'_id': 'Pandora', 'count': 1}
# {'_id': 'Glenview', 'count': 12}
# {'_id': 'Minehead (Somerset)(UK/England)', 'count': 1}
# {'_id': 'Bonne Terre', 'count': 6}
# {'_id': 'Middleboro', 'count': 11}
# {'_id': 'Harlansburgh', 'count': 1}
# {'_id': 'Kokomo', 'count': 40}
# {'_id': 'Spicewood', 'count': 8}
# {'_id': 'Lanexa', 'count': 2}
# {'_id': 'Aurburn', 'count': 2}
# {'_id': 'Fort Collins/Loveland', 'count': 2}
# {'_id': 'Guyana', 'count': 3}
# {'_id': 'Omaha (outside of, near I-80/Westbound)', 'count': 1}
# {'_id': 'Oakland (Near)', 'count': 1}
# {'_id': 'Mckinleyville', 'count': 1}
# {'_id': 'Knoxvile', 'count': 1}
# {'_id': 'Lake Winnibigoshish (North Central MN)', 'count': 1}
# {'_id': 'Columbia (east of city)', 'count': 1}
# {'_id': 'Arleta', 'count': 4}
# {'_id': 'Hanalei Beach', 'count': 1}
# {'_id': 'Clemson', 'count': 5}
# {'_id': 'Sandy Lake', 'count': 1}
# {'_id': 'San Diego', 'count': 523}
# {'_id': 'Ashaway', 'count': 2}
# {'_id': 'Hooker', 'count': 1}
# {'_id': 'Tafton', 'count': 1}
# {'_id': 'Pearl Lake State Park (25 miles north of Steamboat Springs)', 'count': 1}
# {'_id': 'Reynoldsburg (east of)', 'count': 1}
# {'_id': 'Bishopsteignton', 'count': 1}
# {'_id': 'Reunion', 'count': 1}
# {'_id': 'Reinbeck', 'count': 2}
# {'_id': 'Bicknell', 'count': 2}
# {'_id': 'Parker/Aurora', 'count': 1}
# {'_id': 'Providence (On the coastline, SSW of)', 'count': 1}
# {'_id': 'Suffield', 'count': 7}
# {'_id': 'Everson', 'count': 5}
# {'_id': 'Perrine', 'count': 2}
# {'_id': 'Nelson (New Zealand)', 'count': 2}
# {'_id': 'Hurtsboro', 'count': 1}
# {'_id': 'San Diego/Tijuana', 'count': 1}
# {'_id': 'Gay', 'count': 1}
# {'_id': 'Reno/Sun Valley', 'count': 1}
# {'_id': 'Island Pond-Seymour Lake', 'count': 1}
# {'_id': 'Willmar', 'count': 2}
# {'_id': 'Orlando (Lake Downey Park)', 'count': 1}
# {'_id': 'Liberty', 'count': 42}
# {'_id': 'Morrowville', 'count': 1}
# {'_id': 'Pocatello (south of)', 'count': 1}
# {'_id': 'Whitchurch (UK/England)', 'count': 2}
# {'_id': 'Corvalis', 'count': 1}
# {'_id': 'Midland', 'count': 54}
# {'_id': 'Vance', 'count': 4}
# {'_id': 'GLENROCK', 'count': 1}
# {'_id': 'Norwich (Norfolk)(UK/England)', 'count': 1}
# {'_id': 'East Grand Forks', 'count': 4}
# {'_id': 'Delran', 'count': 6}
# {'_id': 'Tinley Park/I-57 (Between, on I 80)', 'count': 1}
# {'_id': 'Penobscot', 'count': 1}
# {'_id': 'Lodi', 'count': 37}
# {'_id': 'Sao Paolo (Brazil)', 'count': 1}
# {'_id': 'Rustington (UK/England)', 'count': 1}
# {'_id': 'Perth (Western Australia)', 'count': 26}
# {'_id': 'Warnambool, VIC (Australia)', 'count': 1}
# {'_id': 'Leeds (outside Birmingham)', 'count': 1}
# {'_id': 'Moab', 'count': 16}
# {'_id': 'St. Louis (South City)', 'count': 1}
# {'_id': 'Templeton', 'count': 6}
# {'_id': 'Zanesville', 'count': 16}
# {'_id': 'Amherst/Tonawanda', 'count': 1}
# {'_id': 'Arlington/Dallas', 'count': 1}
# {'_id': 'El Paso and Alamogordo (Between )', 'count': 1}
# {'_id': 'Gillsville', 'count': 2}
# {'_id': 'Almere (Netherlands)', 'count': 2}
# {'_id': 'Romford (Essex) (UK/England)', 'count': 1}
# {'_id': 'Des Plaines', 'count': 17}
# {'_id': 'Berwick/Wells', 'count': 1}
# {'_id': 'Westmont', 'count': 11}
# {'_id': 'Baltimore City', 'count': 7}
# {'_id': 'Mendon', 'count': 4}
# {'_id': 'In-flight (between TN and CA)', 'count': 1}
# {'_id': 'Mesa (NNE of)', 'count': 1}
# {'_id': 'I-70 (MM-24, eastbound)', 'count': 2}
# {'_id': 'Kelling (UK/England)', 'count': 1}
# {'_id': 'Rockyview County (Canada)', 'count': 1}
# {'_id': 'White Tank Mountains', 'count': 1}
# {'_id': 'Hilliard', 'count': 25}
# {'_id': 'Crescent Beach', 'count': 3}
# {'_id': 'Harrow (Canada)', 'count': 3}
# {'_id': 'Nevada desert (rural; unspecified by witness)', 'count': 1}
# {'_id': 'Moree, NSW (Australia)', 'count': 1}
# {'_id': 'Granite', 'count': 1}
# {'_id': 'Vail', 'count': 12}
# {'_id': 'Armagh (Ireland)', 'count': 1}
# {'_id': 'Kingsford Heights', 'count': 1}
# {'_id': 'Amami (Japan)', 'count': 1}
# {'_id': 'Green Oaks', 'count': 1}
# {'_id': 'Peireus (Greece)', 'count': 1}
# {'_id': 'Toney', 'count': 7}
# {'_id': 'Linn (outside of)', 'count': 1}
# {'_id': 'Jaffrey', 'count': 1}
# {'_id': 'Mahogany Hammock (Everglades Park)', 'count': 1}
# {'_id': 'Campos Altos (Brazil)', 'count': 1}
# {'_id': 'Madrid', 'count': 2}
# {'_id': 'Honokowai', 'count': 1}
# {'_id': 'Summertown, Oxford (UK/England)', 'count': 1}
# {'_id': 'Ocala (Silver Springs Shores)', 'count': 1}
# {'_id': 'Hook Hampshire (UK/England)', 'count': 1}
# {'_id': 'Tuolumne', 'count': 3}
# {'_id': 'Miami', 'count': 353}
# {'_id': 'Crestwood (near St. Louis)', 'count': 1}
# {'_id': 'Pontevedra Beach', 'count': 1}
# {'_id': 'Weston (I-75)', 'count': 1}
# {'_id': 'St. Johns River', 'count': 1}
# {'_id': 'Klamath Falls', 'count': 23}
# {'_id': 'Lyndon Station', 'count': 4}
# {'_id': 'Southwick', 'count': 6}
# {'_id': 'Myles Inlet', 'count': 1}
# {'_id': 'Table Top Mountain', 'count': 1}
# {'_id': 'Ft. White', 'count': 1}
# {'_id': 'St. Catherines (Canada)', 'count': 1}
# {'_id': 'Summerland Key', 'count': 2}
# {'_id': 'Ward', 'count': 6}
# {'_id': 'Myrtle Beach/Conway', 'count': 1}
# {'_id': 'Brunswick Hills', 'count': 1}
# {'_id': 'Bloomington/New Unionville (between)', 'count': 1}
# {'_id': 'Moree (Australia)', 'count': 1}
# {'_id': 'Kennesaw', 'count': 32}
# {'_id': 'IMPERIAL BEACH', 'count': 1}
# {'_id': 'Rizal (Mindanao) (Philippines)', 'count': 1}
# {'_id': 'Readfield', 'count': 1}
# {'_id': 'Antioch Community', 'count': 1}
# {'_id': 'Camborne Cornwall (UK/England)', 'count': 1}
# {'_id': 'San Pedro Town, Ambergris Caye, Belize', 'count': 1}
# {'_id': 'Cheadle (Canada)', 'count': 1}
# {'_id': 'Fortville', 'count': 2}
# {'_id': 'Callands', 'count': 1}
# {'_id': 'Ypsilanti (Pittsfield Township)', 'count': 1}
# {'_id': 'Ft. Lee', 'count': 2}
# {'_id': '54 39 44.6s ,36 11 42.5w', 'count': 1}
# {'_id': 'Sydney (Sydney)', 'count': 1}
# {'_id': 'Liberty Town', 'count': 1}
# {'_id': 'North Myrtle Beach/Loris', 'count': 1}

# %%
cursor=conn.ufo_db.ufo_history.find()
cursor[0]['_id']
# Out:
# ObjectId('630a454ac5d78fb17058edf7')

# %%
db=conn.get_database('ufo_db')
collection=db.ufo_history
collection.count_documents({})
# Out:
# 0

# %%
ufos_hist_read=pd.read_csv('ufos.csv')

# %%
ufos_hist_read.drop(['Unnamed: 0'],axis=1,inplace=True)
ufos_hist_read.rename({'Date / Time':'date_time'},axis=1,inplace=True)
ufos_hist_read.columns=ufos_hist_read.columns.str.lower()
ufos_hist_read['hoax']=0
ufos_hist_read.head(5)
# Out:
#        date_time       city state country     shape          duration  \
# 0  6/22/22 15:45    Hampden    MA     USA      Disk         2 minutes
# 1  6/22/22 10:40  Covington    LA     USA     Cigar        10 seconds
# 2  6/22/22 03:40     Coloma    MI     USA  Changing        5+ minutes
# 3  6/22/22 02:08   Stamford    CT     USA    Circle        10 minutes
# 4  6/21/22 23:15      Arden    NC     USA      Disk  Up to one minute
#
#                                              summary   posted images  hoax
# 0  I Saw a darkish grey disk going in and out of ...  6/22/22    NaN     0
# 1                        Lake Pontchartrain causeway  6/22/22    NaN     0
# 2       Bright light plasma esque possibly spinning?  6/22/22    NaN     0
# 3      Alien being and massive space craft behind it  6/22/22    NaN     0
# 4           I saw it last night dance across the sky  6/22/22    NaN     0

# %%
ufos_hist_read.country.drop_duplicates().to_csv('countries.csv',index=False)

# %%
collection.insert_many(ufos_hist_read.to_dict('records'))

# %%
ufos_hist_read.to_dict('records')[0]
# Out:
# {'Unnamed: 0': 0,
#  'Date / Time': '6/22/22 15:45',
#  'City': 'Hampden',
#  'State': 'MA',
#  'Country': 'USA',
#  'Shape': 'Disk',
#  'Duration': '2 minutes',
#  'Summary': 'I Saw a darkish grey disk going in and out of the clouds.',
#  'Posted': '6/22/22',
#  'Images': nan}
